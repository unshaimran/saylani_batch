# %% [markdown]
# <a href="https://colab.research.google.com/github/unshaimran/saylani_batch/blob/master/While_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greet = True

while greet:
  name = input("Enter your name  : ")

  if name == "exit":
    greet = False
    print(f"Bye, Have a Good Day")
  else:
    print(f"Welcome, {name}")
# Out:
# Enter your name  : unsha
# Welcome, unsha
# Enter your name  : iqra
# Welcome, iqra
# Enter your name  : sara
# Welcome, sara
# Enter your name  : isra
# Welcome, isra
# Enter your name  : yusra
# Welcome, yusra
# Enter your name  : exit
# Bye, Have a Good Day

# %%
even_num = {j : j**2 for j in range(10)}
even_num
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
odd_num = {h : h**3 for h in range(10)}
odd_num
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729}

# %%
even = [j**4 for j in range(10)]
even
# Out:
# [0, 1, 16, 81, 256, 625, 1296, 2401, 4096, 6561]
